# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('usahouseprise.xlsx')
df
# Out:
#    Area  salesprise
# 0  2600      550000
# 1  3000      565000
# 2  3200      610000
# 3  3600      680000
# 4  4000      725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("sales prise")
plt.scatter(df.Area,df.salesprise)

# %%
new_df=df.drop('salesprise',axis='columns')
new_df
# Out:
#    Area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
model=linear_model.LinearRegression()
model.fit(new_df,df.salesprise)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# C:\Users\Sujay Kumar\anaconda3\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])
